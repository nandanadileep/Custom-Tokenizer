# %% [markdown]
# UTF-8 Encoding and Byte-Level Foundations

# %%
samples = [
    "def foo(x): return x**2",
    "get_user_authentication_token",
    "    indented_code",
    "π = 3.14159",
    "emoji 😅 test"
]

for s in samples:
    encoded = s.encode("utf-8")
    decoded = encoded.decode("utf-8")
    print("TEXT:", repr(s))
    print("BYTES:", list(encoded))
    print("DECODED:", repr(decoded))
    print("-" * 40)
# Out:
# TEXT: 'def foo(x): return x**2'
# BYTES: [100, 101, 102, 32, 102, 111, 111, 40, 120, 41, 58, 32, 114, 101, 116, 117, 114, 110, 32, 120, 42, 42, 50]
# DECODED: 'def foo(x): return x**2'
# ----------------------------------------
# TEXT: 'get_user_authentication_token'
# BYTES: [103, 101, 116, 95, 117, 115, 101, 114, 95, 97, 117, 116, 104, 101, 110, 116, 105, 99, 97, 116, 105, 111, 110, 95, 116, 111, 107, 101, 110]
# DECODED: 'get_user_authentication_token'
# ----------------------------------------
# TEXT: '    indented_code'
# BYTES: [32, 32, 32, 32, 105, 110, 100, 101, 110, 116, 101, 100, 95, 99, 111, 100, 101]
# DECODED: '    indented_code'
# ----------------------------------------
# TEXT: 'π = 3.14159'
# BYTES: [207, 128, 32, 61, 32, 51, 46, 49, 52, 49, 53, 57]
# DECODED: 'π = 3.14159'
# ----------------------------------------
# TEXT: 'emoji 😅 test'
# BYTES: [101, 109, 111, 106, 105, 32, 240, 159, 152, 133, 32, 116, 101, 115, 116]
# DECODED: 'emoji 😅 test'
# ...
